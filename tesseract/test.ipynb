# %%
from IPython.display import Image as IImage
from PIL import Image
import pytesseract
from pathlib import Path

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image_dir = Path("test_images")

img_paths = [path for path in image_dir.glob("*.jpg")]

# %%
for img_path in img_paths:
   img = Image.open(img_path)
   display(IImage(img_path, width=500))
   print(pytesseract.image_to_string(img))
# Out:
# Our framework consists of a question answering model and
# < cisadon auiiaiancecner
# ‘We implement two question answering models, which di-
# velly measure the seante alanty between questions
# id eld tadwiert be tx lamaice spsoa: Fy ska
# Dataset Construction Wie build our dataset upon We-
# bascertios stichicvltable toa each
# taps ara ar tesetecie sacaseacgecin ale
# and iplts extacte fon the document by an ape IE a
#
# fenhm (Der Como and Gesu UT). Questions ae cl
# (essed tier We Den TS SPS TORRES gine and dco
# ure collected from a commercial search engune’s search re
# Sc However they do not aaotte which subjecdrg ment
# Hom tiple isthe anier Based os this consideration, we
# take futher anactions in ode o pons ou wich Sub
# Feevargument i the comet answer reduce anata
# fifo. we ake every argument om a comect pt the
# ands asier and provide each anata witha question
# ‘da document Anotaurs are aed to detemsine wheter
# tbjaargurca ia comet awe ot Weassign each
# ‘ands to hee anneatrs and ony calc! he tstance.
#
# ‘isan beled 2 cowrece by los tan tr dnooator,
# boper-ncret srg tapercsiesps treeseese>: | ~ieealena
# idan of sitions in Owe dataset x given tn ToS]
# Seed Copa & penendtne heer mae, eee
# ation wo design ths del sat we walt ase na
# Und language phrases with knowledge based epesenttion
# Wr takes static of 3 euadate answers te np and
# feverales question j- Then prupvasig model gives 3
# Foie Jo(tcd). which is compued between the geterted
# fqestion und the original question qa the rnking score
# Listas sees heget -apemot Segn boaoencamse iia
# Layee based oo the GRU unt The covestnation af the ast
# biden veto fom bath dvctions te sed the question
# vector, The dt products used 0 measure the seman
# relevance between the bb question a two types of ev
# ne
# ‘Despite the interpretability of PCNet, the coverage of at
# shor detection Units the upper bound ofthe approach. We
# implement a move powesul meted based ont eye
# to wet ier 2 KVMemNt ahr
# Stich Ras poner RTENUTTKE-bsed question answer
# Moreover, we mcorporate side information from external
# KBB into thc tee made: The dtl of how we use ex
# femal KBs to eahunce the repwsefation of elements in he
# document KB wil be deseo in secon Incnporsting Ex
# Seal ace
# In this section, we present wo matching models to measure
# the senate telaedess between the question a the eat
# dha ans he vector seman spe. Afterwards, we
# lnoduce ou staen) tat ncorpnstsopca KB seca
# ‘isothadgs to eiaats bah wanda
# ‘QA Model 1: PCNet
