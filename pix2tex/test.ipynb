# %%
from pathlib import Path
from IPython.display import Image as IImage
from PIL import Image
from pix2tex.cli import LatexOCR
from IPython.display import display

# %%
image_dir = Path("test_images")

img_paths = [path for path in image_dir.glob("*.jpg")]

# %%
model = LatexOCR()

# %%
for img_path in img_paths:
   img = Image.open(img_path)
   display(IImage(img_path, width=500))
   print(model(img))
# Out:
# \scriptstyle I_{\mathrm{el}}=\operatorname*{max}\{10,\gamma-s_{e\mathrm{ed}}\{\mathbf{r}^{\mathrm{*}};\mathbf{q}\}+s_{e\mathrm{el}}\{\mathbf{r}^{-};\mathbf{q}\}\}
# \begin{array}{c}{{\mathrm{s}\big(\bar{\cal{C}},\,\vec{\Gamma}\widehat{\scriptscriptstyle{\scriptscriptstyle{\cdot}}}\cdot\vec{q}\big)=\big}_{\begin{array}{c}{{\kappa\in\widehat{E}\widehat{E}\vphantom{L}_{\scriptscriptstyle{K^{\prime}}^{\prime}\left\{\vec{q}\right\},\Gamma\in\vec{R}_{\scriptscriptstyle{\prime}}}}}\\ {{\mathrm{~\vec{\Pi}\acute{\cal{E}}\vphantom{s}^{\prime}\vphantom{\ H}\vphantom{\vphantom{\cal{A}}}_{\vphantom{\Delta}}}\mathrm{\vphantom{\DeltaA}}_{\top}\vphantom{\Delta A}}_{\vphantom{\Delta A}}\mathrm{\cal{\DeltaA}}}\end{array}\big)}}\\ {{\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \left.+\left(\frac{\nabla\mathrm{\bf{\DeltaA}}}{\ldots\vphantom{\Delta A}\mathrm{\cal{A}}_{\small{\cal{A}}}_{\cal{\cal{\Delta A}}}_{\cal{\Delta A}}_{\cal{\cal{\cal{\Delta A}}}}_{\right)}_{\big\ \ \ \ \big\}}_{\ \ \ \ \ \ \ \frac{\ \ \ \ \ \ \ \ \ \ \ \Sigma}_{\ \ \ \ \ \ \right.}_{\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \bot}_{\ \ \ \ \ \frac{\ \{array}
# \tilde{\bar{\Psi}}_{i n k i l e r}\left(\epsilon,\bar{q}\right)=\prod_{\vec{\eta}\vec{n}}\frac{\left|{\cal m}\mid:t\right|}{\left|q\right|}+\frac{\left|{\cal m}\right|\mathrm{i}\mathrm{i}\right|}
# {\Big(}I\equiv\left|j\right|,\left|j\right|,\operatorname*{ma}\right|,\left|j\right|
# \hat{\Psi}\equiv\hat{\phi}|_{*}\langle\partial_{i},...,\hat{\vartheta}_{i}\hat{\vartheta}_{i}
# \scriptstyle\mathbb{N}=\mu_{0}(\mu_{0})_{1}(\beta^{\dagger})
# \begin{array}{r l}{\Omega_{t}^{\mathrm{ort}}=\mathbf{W}^{\mathrm{int}}\mathbf{h}_{t}^{\mathrm{int}},\quad l\in[1,n]\}}\\ {\operatorname{secoge}(\mathbf{X},\mathbf{y})=\sum_{i=1}^{n}(\mathbf{o}_{l,\mathrm{y}_{i}}+T_{\mathrm{pt-i,j_{i}}})}\\ {\operatorname{secofe}(\mathbf{X},\mathbf{y})=\sum_{i=1}^{n}(\mathbf{scofi}(\mathbf{X},\mathbf{y})).}\end{array}
# {\mathfrak{p}}[{\mathfrak{I}}]\mathbf{X})={\frac{\operatorname{extp}\left(\operatorname{secore}(\mathbf{X}.{\bar{\mathfrak{Y}}})\right)}{\sum_{\mathbf{Y}}\ E_{\mathbf{X}}\operatorname{exp}\left(\operatorname{score}[\mathbf{X}.\mathbf{y}\right)\right)}}
# \log\!\left[\Theta,\mathbf{X}.{\mathfrak{Y}}\right]=-\log p\left[{\tilde{\mathfrak{Y}}}\right]\!\mathbf{X}\right)
# \begin{array}{l}{{\displaystyle{\mid}_{I}^{\mathrm{{lothar}}}=\displaystyle{\mid}\bigcup_{i=1,i=1,i=1,i=1,i}^{\mathrm{{lothi}}}\overbrace{\overbrace{\longrightarrow}^{\frac{n}{3}}\mid}_{\displaystyle{\mid}}^{\mathrm{{lothi}}}\Big|\Delta_{I=\frac{n}{2}}^{\mathrm{{lor}}\atop{\mid}\atop{\mid}\mathrm{{lifli}_{\mathrm{{l}}}=\ \|\Delta\mid}^{\scriptstyle{\mid}_{\mathrm{diffi}}},\cdot\cdot{,\quad}\quad{\mid}_{i\atop{\mid}_{\mathrm{(il}}\atop{\mid}=\mid}}}\\ {{\mid}_{\mathrm{{loildr}}}=\|_{i}\|\delta\|_{i}\|\ \|_{i}\|\ \|_{\mathrm{{lifli}_{\thinspace i}^{\mathrm{{\bfli}}}}\|_{\tt j}_{\tt{l i}}}^{\\|_{\tt i}_{\ \|}_{\tt i l i l i}^{\tt{\tt{\mathrm{\tt}}_{\tt{\mid}_{\leq}}_{\mid}_{\tt{\leq}_{\mid}_{\mid}_{\atop{\mid}_{\mid}}_{\ \|}}_{\Delta_{\leq i}\|}\|_{\mid}}_{\tt{\ \|}\|_{\ \|}\|}\|}_{\tt{\ \|_{\ \|_{\ \|}\|}\|_{\ \|
# \begin{array}{l l}{{\Phi=\arg\operatorname*{min}\mathrm{R}(\Im,\Theta^{\prime},{\bf X},{\bf\bar{x}})}}&{{\qquad}}\\ {{\displaystyle\left.\bar{\Theta}^{\prime}=\arg\bigoplus_{\alpha\nu}^{\mathrm{max}}\mathrm{R}(\bar{\Theta},\Theta^{\prime},{\bf X},{\bf\bar{y}},{\bar{z}})}}&{{\qquad}}&{{\langle{\bf12}\rangle}}\end{array}
# p(\bar{z}|{\bf X},\bar{\bf y})=\sum_{\bar{z}=\bar{z}\in\bar{z}|\bar{p}|(\Omega_{z}^{\mathrm{qer}|z=\bar{p}})}.
# \begin{array}{l}{{\left|{\bf{r}}\!\mathrm{d}\mathrm{u}\mathrm{v}\,\mathrm{t}\mathrm{sun}\mathrm{u}\mathrm{s}\mathrm{\u}\mathrm{n}\mathrm{s}\ \mathrm{un}\mathrm{u}\mathrm{n}\mathrm{n}\mathrm{s}\ \mathrm{un}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{n}\mathrm{b}\mathrm{s}\right.}}}\\ {{\mathrm{R}\langle\!\Theta,\bar{\vartheta}_{,}{\bf{X}}_{,}{\bf{\bar{y}}}_{,}{\bf{\bar{z}}}\rangle=\mathrm{los}\mathrm{p}\mathrm{f}\mathrm{d}\mathrm{T}\mathrm{i}\mathrm{i}\mathrm{X}\rangle+\mathrm{los}\mathrm{f}\mathrm{f}\mathrm{i}\mathrm{i}\mathrm{T}\mathrm{i}\mathrm{i}\mathrm{i}\mathrm{i}\mathrm{x}\mathrm{\mathrm{i}\bf{\bf{\mathrm{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\mathrm{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\bar{\prime}}}}}\bar{\bar{\bar{\bar{\bar{\bar{\bar
# \begin{array}{c c}{{\mathrm{i}{\cal P}{\cal D}_{D\bar{U}}[j]=\displaystyle{\frac{{\cal D}[j]}{\mathrm{h}_{\Delta\bar{X}}^{t r i u\bar{A}}}{\hat{t}}_{i}}{\left.\right.}}}&{{\langle\mathrm{i}\rangle}}\\ {{\mathrm{i}u^{\bar{t}}{\epsilon}{\epsilon}{\cdot}{\kappa}_{\bar{-}}}}&{{\mathrm{i}<\mathrm{~j}\!\!\bar{h}}{\scriptstyle\!\mathrm{~}}\!\!\mathrm{i}}\!\!\mathrm{a}\!\!\left|{\bar{\theta}}{\epsilon}_{-}{\bar{\epsilon}}\!\!\mathrm{i}}\!\!\right.\quad(\mathrm{i})}}\\ {{\mathrm{u}^{\mathrm{i}\bar{h}_{i}{\epsilon}\!\sigma}_{-}{\tau}_{\mathrm{-}}\!\mathrm{i}<\mathrm{~}{\bar{\it\int}}\!\!\mathrm{i}}\!\!\mathrm{i}_{i}_{i}{\epsilon}_{-}\!\epsilon}\!\mathrm{i}_{\sigma}}_{-}\mathrm{\epsilon}_{\epsilon}}^{{\epsilon}_{\epsilon}_{\epsilon}}\mathrm{\epsilon}_{\mathrm{\epsilon}}_{\mathrm{\epsilon}_{\epsilon}}_{-}_{\epsilon}_{{\mathrm{\epsilon}_{\mathrm{-}}}_{\epsilon}}_{i}_{\epsilon}_{\epsilon}_{\mathrm{\epsilon}_{\epsilon}_{\mathrm{\epsilon}_{
# \textstyle\int_{\mathbb{R}}\left(q_{i}\,a\right)=v_{q}^{T}\,v_{i}+v_{q}^{T}
# \Omega_{k e w_{1*}}=s\omega{\it f}{\it f}m a x{\lbrace v_{\mathrm{w}}\cdot v_{\mathrm{kew_{i}}\rbrace}}
# \textstyle\sum_{i=1}^{n}
# \sum_{n=1}^{n+1}\sum_{a=1}^{\infty}\operatorname*{max}\{(0,m-S(q_{i},\alpha_{i})+S(q_{i},\bar{\alpha})\}
# \stackrel{\lbrack\beta\rbrack}{\cal{\lbrack\beta\rbrack}=\mathrm{d}[\stackrel{\psi}{\hbar}]\lbrack\mathrm{d},\stackrel{\lbrack\beta]}{\hbar}\stackrel{\lbrack\beta\rbrack}{\xi},\stackrel{\lbrack\beta\rbrack}\stackrel{\lbrack\beta\rbrack}{\theta}^{\prime}]
# S=\int_{x}\left\{\frac{1}{2}\sum_{a}\partial^{\mu}\chi_{a}\partial_{\mu}\chi_{a}+V(\rho)\right\}

# %%
# print image
